# %%
import pandas as pd
data_path = "./data/total_data2.xlsx"
data = pd.read_excel('./data/total_data2.xlsx')

# %%
user_dict = {}

for data in data.iterrows():
    print(data)
# Out:
# (0, USER_ID               admin
# date               20230622
# call_duration            83
# db_value_mean          56.0
# db_value_max             61
# db_value_min             51
# heart_rate_mean        69.5
# heart_rate_max           71
# heart_rate_min           68
# lux_value_mean        551.0
# lux_value_max           990
# lux_value_min           112
# msg_num                   9
# pic_num                   1
# sleep_duration          420
# step_count            13595
# app_acc                   7
# app_audio                 3
# app_game                  9
# app_img                   4
# app_maps                  5
# app_news                 11
# app_video                 2
# Name: 0, dtype: object)
# (1, USER_ID               admin
# date               20230623
# call_duration          1197
# db_value_mean          76.5
# db_value_max             97
# db_value_min             56
# heart_rate_mean        73.5
# heart_rate_max           86
# heart_rate_min           61
# ...
