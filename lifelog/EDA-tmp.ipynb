# %%
# 필요한 라이브러리를 가져옵니다
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 수집
# 여기에서 데이터를 수집하는 코드를 작성합니다. 데이터는 파일에서 읽어오거나 API를 통해 가져올 수 있습니다.
# 예를 들어 CSV 파일을 불러올 때는 pandas의 read_csv 함수를 사용할 수 있습니다.
data = pd.read_csv("./data/result.csv")
data = data.iloc[:, 3:]
data = data.fillna(data.mean())

print("dtypes : ", data.dtypes)
print("describe : ", data.describe(include='all'))
# Out:
# dtypes :  call_duration     float64
# db_value_mean     float64
# db_value_max      float64
# db_value_min      float64
# lux_value_mean    float64
# lux_value_max     float64
# lux_value_min     float64
# msg_num           float64
# pic_num           float64
# sleep_duration    float64
# step_count        float64
# label               int64
# dtype: object
# describe :         call_duration  db_value_mean  db_value_max  db_value_min  \
# count     534.000000     534.000000    534.000000    534.000000
# mean      204.500000      58.016306     64.165644     52.165644
# std        54.556372       6.669728      7.646079      7.547539
# min         0.000000      32.000000     32.000000     31.000000
# 25%       204.500000      58.016306     64.165644     52.165644
# 50%       204.500000      58.016306     64.165644     52.165644
# 75%       204.500000      58.016306     64.165644     52.165644
# max       933.000000      90.000000     90.000000     90.000000
#
#        lux_value_mean  lux_value_max  lux_value_min     msg_num     pic_num  \
# count      534.000000     534.000000     534.000000  534.000000  534.000000
# mean       445.995719     619.485549     288.161850    2.343558    9.662338
# std       1116.121047    1339.527776     974.972608    1.289851   21.378835
# min          0.000000       0.000000       0.000000    1.000000    1.000000
# 25%        308.500000     447.250000     132.750000    2.343558    2.000000
# 50%        445.995719     619.485549     288.161850    2.343558    8.000000
# 75%        445.995719     619.485549     288.161850    2.343558    9.662338
# max      20792.500000   21014.000000   20571.000000   12.000000  396.000000
#
#        sleep_duration    step_count  label
# count      534.000000    534.000000  534.0
# mean       465.407895   4881.324561    0.0
# std         71.636779   1866.976778    0.0
# min        190.000000     14.000000    0.0
# 25%        465.407895   4881.324561    0.0
# 50%        465.407895   4881.324561    0.0
# 75%        465.407895   4881.324561    0.0
# max       1213.000000  18473.000000    0.0

# %%
data.hist(alpha=0.5, figsize=(10, 8))
plt.show()

# %%
data.plot.hist(alpha=0.5)
plt.show()

# %%
data.boxplot(by='label', figsize=(10, 10))
# Out:
# array([[<Axes: title={'center': 'call_duration'}, xlabel='[label]'>,
#         <Axes: title={'center': 'db_value_max'}, xlabel='[label]'>,
#         <Axes: title={'center': 'db_value_mean'}, xlabel='[label]'>],
#        [<Axes: title={'center': 'db_value_min'}, xlabel='[label]'>,
#         <Axes: title={'center': 'lux_value_max'}, xlabel='[label]'>,
#         <Axes: title={'center': 'lux_value_mean'}, xlabel='[label]'>],
#        [<Axes: title={'center': 'lux_value_min'}, xlabel='[label]'>,
#         <Axes: title={'center': 'msg_num'}, xlabel='[label]'>,
#         <Axes: title={'center': 'pic_num'}, xlabel='[label]'>],
#        [<Axes: title={'center': 'sleep_duration'}, xlabel='[label]'>,
#         <Axes: title={'center': 'step_count'}, xlabel='[label]'>,
#         <Axes: >]], dtype=object)

# %%
g = sns.pairplot(data, hue='label', diag_kind='hist', height=2.5)
# Out:
# C:\Users\user\Anaconda3\envs\lifelog\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
corr = data.iloc[:, :-1].corr()

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(corr, annot=True, cmap="PuBu")
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')
